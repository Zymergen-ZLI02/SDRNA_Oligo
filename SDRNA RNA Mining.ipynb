# %%
import os
from Bio import SeqIO
from pathlib import Path

# %%
def SDRNA_RNA_Mining(foldername):
    pathname = Path(foldername + "/")
    filelist = os.listdir(pathname)
    opname = foldername + " output.fasta"
    output_file = pathname / opname
    f = open(output_file, "w")
    
    for fn in range(len(filelist)):
        gbfile = filelist[fn]
        input_file = pathname / gbfile
    
        for rec in SeqIO.parse(input_file, "gb"): 
            acc = rec.annotations['accessions'][0]
            name = rec.name 
            seq = rec.seq

            for feature in rec.features:
                ifrrRNA = 0

                if "rRNA" in feature.type:
                    ifrrRNA = 1
                else:
                    for key, val in feature.qualifiers.items(): #looks for val in the feature qualifiers

                        if (any("rRNA" in s for s in val) and 
                            "CDS" in feature.type.upper() and 
                            (not("complex" in val[0].lower() or 
                                 "protein" in val[0].lower()))):
                            ifrrRNA = 1

                if ifrrRNA == 1:
                    print(feature)

                    seqstart = feature.location.start.position
                    seqend = feature.location.end.position

                    if feature.location.strand == 1:
                        strdir = "forward"
                        rRNAseq = seq[seqstart:seqend]
                    elif feature.location.strand == -1:
                        strdir = "revcomp"
                        rRNAseq = seq[seqstart:seqend].reverse_complement()[::]
                    else:
                        strdir = ""

                    if "display" in feature.qualifiers:
                        addinfo = feature.qualifiers["display"][0]
                    elif "note" in feature.qualifiers:
                        addinfo = feature.qualifiers["note"][0]
                    else:
                        addinfo = ""

                    f.write(">{0}|{1}|{2}-{3}|{4}|{5}|{6}| \n{7}\n".format(acc, name,
                                                                           seqstart, seqend, strdir,
                                                                           feature.qualifiers["annotationName"][0],
                                                                           addinfo, 
                                                                           rRNAseq))
    f.close()
    
foldername = "SC 7000071044"
SDRNA_RNA_Mining(foldername)
# Out:
# type: CDS
# location: [431333:438191](-)
# qualifiers:
#     Key: ID, Value: ['RDN37-1']
#     Key: annotationName, Value: ['RDN37-1']
#     Key: createTimestamp, Value: ['1562023317167']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000006486']
#     Key: description, Value: [' ']
#     Key: display, Value: ['35S ribosomal RNA (35S rRNA) transcript']
#     Key: gene, Value: ['RDN37-1']
#     Key: gene_synonym, Value: ['RDN37']
#     Key: label, Value: ['RDN37-1']
#     Key: source, Value: ['SGD', 'liftover']
#
# type: CDS
# location: [431544:434940](-)
# qualifiers:
#     Key: Alias, Value: ['26S rRNA']
#     Key: ID, Value: ['RDN25-1']
#     Key: Ontology_term, Value: ['GO:0022625']
#     Key: annotationName, Value: ['RDN25-1']
#     Key: createTimestamp, Value: ['1562023317167']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000006484']
#     Key: description, Value: [' ']
#     Key: display, Value: ['25S ribosomal RNA (25S rRNA)']
#     Key: gene, Value: ['RDN25-1']
#     Key: gene_synonym, Value: ['RDN25']
#     Key: label, Value: ['RDN25-1']
#     Key: source, Value: ['SGD', 'liftover']
#
# type: CDS
# location: [435198:435356](-)
# qualifiers:
#     Key: ID, Value: ['RDN58-1']
#     Key: Ontology_term, Value: ['GO:0022625']
#     Key: annotationName, Value: ['RDN58-1']
#     Key: createTimestamp, Value: ['1562023317167']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000006488']
#     Key: description, Value: [' ']
#     Key: display, Value: ['5.8S ribosomal RNA (5.8S rRNA)']
#     Key: gene, Value: ['RDN58-1']
#     Key: gene_synonym, Value: ['RDN58']
#     Key: label, Value: ['RDN58-1']
#     Key: source, Value: ['SGD', 'liftover']
#
# type: CDS
# location: [442957:443078](+)
# qualifiers:
#     Key: ID, Value: ['RDN5-6']
#     Key: Ontology_term, Value: ['GO:0008150']
#     Key: annotationName, Value: ['RDN5-6']
#     Key: createTimestamp, Value: ['1562023317167']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000029711']
#     Key: description, Value: [' ']
#     Key: display, Value: ['Variant 5S ribosomal rRNA (5S rRNA) gene']
#     Key: gene, Value: ['RDN5-6']
#     Key: gene_synonym, Value: ['RDN5']
#     Key: label, Value: ['RDN5-6']
#     Key: source, Value: ['SGD', 'liftover']
#
# type: CDS
# location: [98295:102619](+)
# qualifiers:
#     Key: ID, Value: ['Q0158']
#     Key: Ontology_term, Value: ['GO:0042255']
#     Key: annotationName, Value: ['Q0158']
#     Key: createTimestamp, Value: ['1562023344215']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000007288']
#     Key: description, Value: [' ']
#     Key: display, Value: ['Mitochondrial 21S rRNA']
#     Key: gene, Value: ['21S_RRNA']
#     Key: gene_synonym, Value: ['21S_rRNA_4']
#     Key: label, Value: ['Q0158']
#     Key: source, Value: ['SGD', 'liftover']
#
# type: CDS
# location: [221810:222692](-)
# qualifiers:
#     Key: Alias, Value: ["Subunit of both RNase MRP, which cleaves pre-rRNA, and nuclear RNase P, which cleaves tRNA precursors to generate mature 5' ends"]
#     Key: ID, Value: ['YHR062C_CDS']
#     Key: Parent, Value: ['YHR062C_mRNA']
#     Key: annotationName, Value: ['YHR062C_CDS']
#     Key: codon_start, Value: ['1']
#     Key: createTimestamp, Value: ['1562023291957']
#     Key: creatorId, Value: ['16703']
#     Key: description, Value: [' ']
#     Key: gene, Value: ['RPP1']
#     Key: label, Value: ['YHR062C_CDS']
#     Key: note, Value: ["Subunit of both RNase MRP, which cleaves pre-rRNA, and nuclear RNase P, which cleaves tRNA precursors to generate mature 5' ends"]
#     Key: phase, Value: ['0']
#     Key: product, Value: ['Rpp1p']
#     Key: protein_id, Value: ['EIW09959.1']
#     Key: source, Value: ['liftover']
#
# type: CDS
# location: [46752:48440](+)
# qualifiers:
#     Key: Alias, Value: ['14s rRNA']
#     Key: ID, Value: ['Q0020']
#     Key: Ontology_term, Value: ['GO:0042255']
#     Key: annotationName, Value: ['Q0020']
#     Key: createTimestamp, Value: ['1562023346764']
#     Key: creatorId, Value: ['16703']
#     Key: dbxref, Value: ['SGD:S000007287']
#     Key: description, Value: [' ']
#     Key: display, Value: ['Ribosomal RNA of the small mitochondrial ribosomal subunit']
#     Key: gene, Value: ['15S_RRNA']
#     Key: gene_synonym, Value: ['15S_RRNA_2']
#     Key: label, Value: ['Q0020']
#     Key: source, Value: ['SGD', 'liftover']

# %%
"""
import Tkinter as tk
import tkFileDialog

root = Tkinter.Tk()
filez = tkFileDialog.askopenfilenames(parent=root,title='Choose a file')
print root.tk.splitlist(filez)

data_folder = Path("Project_3_Seq_Test/KP 7000772268/")
file_to_open = data_folder / "13005730928.gb"
print(file_to_open.read_text())


"""
